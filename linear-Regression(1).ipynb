# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
train=pd.read_csv(r"C:\Users\Mai\Downloads\1553768847-housing.csv")
train.head(10)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                  41          880           129.0
# 1    -122.22     37.86                  21         7099          1106.0
# 2    -122.24     37.85                  52         1467           190.0
# 3    -122.25     37.85                  52         1274           235.0
# 4    -122.25     37.85                  52         1627           280.0
# 5    -122.25     37.85                  52          919           213.0
# 6    -122.25     37.84                  52         2535           489.0
# 7    -122.25     37.84                  52         3104           687.0
# 8    -122.26     37.84                  42         2555           665.0
# 9    -122.25     37.84                  52         3549           707.0
#
#    population  households  median_income ocean_proximity  median_house_value
# 0         322         126         8.3252        NEAR BAY              452600
# 1        2401        1138         8.3014        NEAR BAY              358500
# 2         496         177         7.2574        NEAR BAY              352100
# 3         558         219         5.6431        NEAR BAY              341300
# 4         565         259         3.8462        NEAR BAY              342200
# 5         413         193         4.0368        NEAR BAY              269700
# 6        1094         514         3.6591        NEAR BAY              299200
# 7        1157         647         3.1200        NEAR BAY              241400
# 8        1206         595         2.0804        NEAR BAY              226700
# 9        1551         714         3.6912        NEAR BAY              261100

# %%
x= train.drop('median_house_value', axis=1)  
y= train['median_house_value']

# %%
x.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# ocean_proximity         0
# dtype: int64

# %%
y.isnull().sum()
# Out:
# 0

# %%
x['total_bedrooms'] = x['total_bedrooms'].fillna(x['total_bedrooms'].mean())

# %%
x.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# ocean_proximity       0
# dtype: int64

# %%
x = pd.get_dummies(x, columns=['ocean_proximity'])

# %%
x.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                  41          880           129.0
# 1    -122.22     37.86                  21         7099          1106.0
# 2    -122.24     37.85                  52         1467           190.0
# 3    -122.25     37.85                  52         1274           235.0
# 4    -122.25     37.85                  52         1627           280.0
#
#    population  households  median_income  ocean_proximity_<1H OCEAN  \
# 0         322         126         8.3252                      False
# 1        2401        1138         8.3014                      False
# 2         496         177         7.2574                      False
# 3         558         219         5.6431                      False
# 4         565         259         3.8462                      False
#
#    ocean_proximity_INLAND  ocean_proximity_ISLAND  ocean_proximity_NEAR BAY  \
# 0                   False                   False                      True
# 1                   False                   False                      True
# 2                   False                   False                      True
# 3                   False                   False                      True
# 4                   False                   False                      True
#
#    ocean_proximity_NEAR OCEAN
# 0                       False
# 1                       False
# 2                       False
# 3                       False
# 4                       False

# %%
Q1 = data.quantile(0.25)
Q3 = data.quantile(0.75)
IQR = Q3 - Q1
outliers = data[(data < Q1 - 1.5 * IQR) | (data > Q3 + 1.5 * IQR)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 Q1 = data.quantile(0.25)
#       2 Q3 = data.quantile(0.75)
#       3 IQR = Q3 - Q1
#
# NameError: name 'data' is not defined

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test= train_test_split(x, y, test_size=0.2, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
x_train_scaling = scaler.fit_transform(x_train)
x_test_scaling = scaler.transform(x_test)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(x_train_scaling, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(x_test_scaling)

# %%
y_pred
# Out:
# array([216580.43445119, 287452.10783574, 179457.58064554, ...,
#         89138.63966549, 255304.51129843, 213286.39732918])

# %%
y_pred = pd.DataFrame(y_pred)
y_pred
# Out:
#                   0
# 0     216580.434451
# 1     287452.107836
# 2     179457.580646
# 3      86485.418340
# 4     291756.937449
# ...             ...
# 4123  171472.200850
# 4124  245342.253196
# 4125   89138.639665
# 4126  255304.511298
# 4127  213286.397329
#
# [4128 rows x 1 columns]

# %%
y_test
# Out:
# 14740    136900
# 10101    241300
# 20566    200700
# 2670      72500
# 15709    460000
#           ...
# 6655     169500
# 3505     204600
# 1919     128600
# 1450     259500
# 4148     167600
# Name: median_house_value, Length: 4128, dtype: int64

# %%
y_test= pd.DataFrame(y_test)
y_test
# Out:
#        median_house_value
# 14740              136900
# 10101              241300
# 20566              200700
# 2670                72500
# 15709              460000
# ...                   ...
# 6655               169500
# 3505               204600
# 1919               128600
# 1450               259500
# 4148               167600
#
# [4128 rows x 1 columns]

# %%
y_test = pd.DataFrame(y_test).reset_index(drop=True)
y_test
# Out:
#       median_house_value
# 0                 136900
# 1                 241300
# 2                 200700
# 3                  72500
# 4                 460000
# ...                  ...
# 4123              169500
# 4124              204600
# 4125              128600
# 4126              259500
# 4127              167600
#
# [4128 rows x 1 columns]

# %%
from sklearn.metrics import mean_squared_error, root_mean_squared_error,mean_absolute_error

mse = mean_squared_error(y_test, y_pred)
rmse = root_mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
print(f"Mean Squared Error: {mse}")
print(f"Mean absolute Error: {mae}")
print(f"Root Mean Squared Error: {rmse}")
# Out:
# Mean Squared Error: 4718206968.301578
# Mean absolute Error: 49697.07016481124
# Root Mean Squared Error: 68689.20561705148

# %%
r_squared = r2_score(y_test, y_pred)
print(f"R-squared score: {r_squared}")
# Out:
# R-squared score: 0.6381617983930403
